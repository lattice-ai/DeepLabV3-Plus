# %% [markdown]
# <a href="https://colab.research.google.com/github/soumik12345/DeepLabV3-Plus/blob/feature%2Fbackbones/notebooks/Train_Demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !nvidia-smi
# Out:
# Sat Aug 22 12:38:02 2020
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 450.57       Driver Version: 418.67       CUDA Version: 10.1     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  Tesla T4            Off  | 00000000:00:04.0 Off |                    0 |
# | N/A   54C    P8    11W /  70W |      0MiB / 15079MiB |      0%      Default |
# |                               |                      |                 ERR! |
# +-------------------------------+----------------------+----------------------+
#
# ...

# %%
# !pip install --upgrade wandb
# Out:
# ...
#      |████████████████████████████████| 1.4MB 4.8MB/s
# ...
#      |████████████████████████████████| 163kB 13.2MB/s
# ...
#      |████████████████████████████████| 102kB 10.6MB/s
# ...
#      |████████████████████████████████| 102kB 9.6MB/s
# ...
#      |████████████████████████████████| 122kB 20.5MB/s
# ...
#      |████████████████████████████████| 71kB 9.3MB/s
# ...
#      |████████████████████████████████| 71kB 9.3MB/s
# ...
#   Created wheel for gql: filename=gql-0.2.0-cp36-none-any.whl size=7630 sha256=a79bd3b5589195ad92b869b58e94c6806dcc2670466926531e3477e15566d2d7
#   Stored in directory: /root/.cache/pip/wheels/ce/0e/7b/58a8a5268655b3ad74feef5aa97946f0addafb3cbb6bd2da23
# ...
#   Created wheel for watchdog: filename=watchdog-0.10.3-cp36-none-any.whl size=73870 sha256=aaa9e490bb4aca19210b61c0ac1ae63776cf44db1f0084c8eb49479b7b4874af
#   Stored in directory: /root/.cache/pip/wheels/a8/1d/38/2c19bb311f67cc7b4d07a2ec5ea36ab1a0a0ea50db994a5bc7
# ...

# %%
# !git clone https://github.com/soumik12345/DeepLabV3-Plus -b feature/backbones
# %cd DeepLabV3-Plus/dataset
# !sh camvid.sh
# %cd ..
# Out:
# fatal: destination path 'DeepLabV3-Plus' already exists and is not an empty directory.
# /content/DeepLabV3-Plus/dataset
# mkdir: cannot create directory ‘camvid’: File exists
# --2020-08-22 12:38:33--  https://www.dropbox.com/s/ej1gx48bxqbtwd2/CamVid.zip?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.1.1, 2620:100:6016:1::a27d:101
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.1.1|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/raw/ej1gx48bxqbtwd2/CamVid.zip [following]
# --2020-08-22 12:38:33--  https://www.dropbox.com/s/raw/ej1gx48bxqbtwd2/CamVid.zip
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://uca7c89182c64595ccc9ddee44d8.dl.dropboxusercontent.com/cd/0/inline/A9_rv-ca2Ma1aLFrcUO3qqZOftHeOT9UifIdJISXSzEBYTIW-Q65bqjwtWWw5r-rYsxQbuTXSHw3p9gm5XJsNnwLeKToAHtcXmCdiXiKDvb26dqhwntpzVEQqF6lcRAzq-k/file# [following]
# ...

# %%
# !python trainer.py --wandb_api_key 60cfb770bc5de44f181c8cb5e270eb266bc918c6 camvid_resnet50
# Out:
# [-] Importing tensorflow...
# 2020-08-22 12:38:55.383693: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# [+] Done! Tensorflow version: 2.3.0
# [-] Importing Deeplabv3plus Trainer class...
# [-] Importing config files...
# 2020-08-22 12:38:57.049589: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2020-08-22 12:38:57.106828: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2020-08-22 12:38:57.107475: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.73GiB deviceMemoryBandwidth: 298.08GiB/s
# ...
